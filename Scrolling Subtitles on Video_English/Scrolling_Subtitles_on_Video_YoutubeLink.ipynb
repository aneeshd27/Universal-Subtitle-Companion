# %%
# !pip install -q ipython-autotime
# Out:
# time: 5.22 s (started: 2023-10-27 13:23:20 +00:00)

# %%
# %load_ext autotime
# Out:
# The autotime extension is already loaded. To reload it, use:
#   %reload_ext autotime
# time: 1.77 ms (started: 2023-10-27 13:23:25 +00:00)

# %%
# !pip install -q pytube
# Out:
# time: 4.62 s (started: 2023-10-27 13:23:25 +00:00)

# %%
import os
from pytube import YouTube
#videofilename="/content/video.mp4"
videofilename = input("Enter the path of mp4/Youtube Link: ")

if "youtube.com" in videofilename:
    video_instance = YouTube(videofilename)
    stream = video_instance.streams.get_highest_resolution()

    stream.download()
    print("Download completed.")
else:
    print("Inputted file is a local file.")
# Out:
# Enter the path of mp4/Youtube Link: https://www.youtube.com/watch?v=JzPfMbG1vrE
# Download completed.
# time: 13.5 s (started: 2023-10-27 13:23:30 +00:00)

# %%
videofilename="/content/youtubevideo.mp4"
# Out:
# time: 395 µs (started: 2023-10-27 13:23:43 +00:00)

# %%
# !pip install -q ffmpeg-python==0.2.0
# Out:
# time: 6.54 s (started: 2023-10-27 13:23:44 +00:00)

# %%
import ffmpeg

audiofilename = videofilename.replace(".mp4",'.mp3')

# Create the ffmpeg input stream
input_stream = ffmpeg.input(videofilename)

# Extract the audio stream from the input stream
audio = input_stream.audio

# Save the audio stream as an MP3 file
output_stream = ffmpeg.output(audio, audiofilename)

# Overwrite output file if it already exists
output_stream = ffmpeg.overwrite_output(output_stream)

ffmpeg.run(output_stream)

print (audiofilename)
# Out:
# /content/youtubevideo.mp3
# time: 1.78 s (started: 2023-10-27 13:23:50 +00:00)

# %%
from IPython.display import Audio
Audio(audiofilename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# time: 47.1 ms (started: 2023-10-27 13:23:52 +00:00)

# %%
# !pip install -q faster-whisper==0.7.0
# Out:
# time: 5.14 s (started: 2023-10-27 13:23:52 +00:00)

# %%
from faster_whisper import WhisperModel

model_size = "medium"
model = WhisperModel(model_size)
# Out:
# time: 949 ms (started: 2023-10-27 13:23:57 +00:00)

# %% [markdown]
# #Generate Subtitles

# %%
segments, info = model.transcribe(audiofilename, word_timestamps=True)
segments = list(segments)  # The transcription will actually run here.
for segment in segments:
    for word in segment.words:
        print("[%.2fs -> %.2fs] %s" % (word.start, word.end, word.word))
# Out:
# [7.14s -> 7.78s]  So,
# [11.94s -> 12.08s]  you're
# [12.08s -> 12.38s]  running
# [12.38s -> 12.58s]  a
# [12.58s -> 12.76s]  little
# [12.76s -> 13.02s]  late
# [13.02s -> 13.50s]  today.
# [13.92s -> 14.24s]  And
# [14.24s -> 14.38s]  you
# [14.38s -> 14.56s]  haven't
# [14.56s -> 14.74s]  had
# [14.74s -> 15.08s]  your
# [15.08s -> 15.32s]  fresh
# [15.32s -> 15.58s]  cup
# [15.58s -> 15.76s]  of
# [15.76s -> 16.00s]  coffee
# [16.00s -> 16.38s]  yet.
# [17.72s -> 17.94s]  No
# [17.94s -> 18.18s]  matter
# [18.18s -> 18.46s]  the
# [18.46s -> 18.72s]  weather
# [18.72s -> 19.08s]  or
# [19.08s -> 19.58s]  traffic,
# [19.82s -> 20.04s]  we
# [20.04s -> 20.46s]  deliver
# [20.46s -> 20.92s]  fresh
# [20.92s -> 21.34s]  coffee
# [21.34s -> 21.82s]  and
# [21.82s -> 22.52s]  bagels.
# [25.60s -> 26.24s]  The
# [26.24s -> 26.70s]  Java
# [26.70s -> 27.26s]  Cafe.
# time: 1.1 s (started: 2023-10-27 13:23:58 +00:00)

# %%
wordlevel_info = []

for segment in segments:
    for word in segment.words:
      wordlevel_info.append({'word':word.word,'start':word.start,'end':word.end})
# Out:
# time: 551 µs (started: 2023-10-27 13:23:59 +00:00)

# %%
wordlevel_info
# Out:
# [{'word': ' So,', 'start': 7.14, 'end': 7.78},
#  {'word': " you're", 'start': 11.94, 'end': 12.08},
#  {'word': ' running', 'start': 12.08, 'end': 12.38},
#  {'word': ' a', 'start': 12.38, 'end': 12.58},
#  {'word': ' little', 'start': 12.58, 'end': 12.76},
#  {'word': ' late', 'start': 12.76, 'end': 13.02},
#  {'word': ' today.', 'start': 13.02, 'end': 13.5},
#  {'word': ' And', 'start': 13.92, 'end': 14.24},
#  {'word': ' you', 'start': 14.24, 'end': 14.38},
#  {'word': " haven't", 'start': 14.38, 'end': 14.56},
#  {'word': ' had', 'start': 14.56, 'end': 14.74},
#  {'word': ' your', 'start': 14.74, 'end': 15.08},
#  {'word': ' fresh', 'start': 15.08, 'end': 15.32},
#  {'word': ' cup', 'start': 15.32, 'end': 15.58},
#  {'word': ' of', 'start': 15.58, 'end': 15.76},
#  {'word': ' coffee', 'start': 15.76, 'end': 16.0},
#  {'word': ' yet.', 'start': 16.0, 'end': 16.38},
#  {'word': ' No', 'start': 17.72, 'end': 17.94},
#  {'word': ' matter', 'start': 17.94, 'end': 18.18},
# ...

# %%
import json
with open('data.json', 'w') as f:
    json.dump(wordlevel_info, f,indent=4)
# Out:
# time: 4.48 ms (started: 2023-10-27 13:23:59 +00:00)

# %%
def split_text_into_lines(data):

    MaxChars = 30
    #maxduration in seconds
    MaxDuration = 2.5
    #Split if nothing is spoken (gap) for these many seconds
    MaxGap = 1.5

    subtitles = []
    line = []
    line_duration = 0
    line_chars = 0


    for idx,word_data in enumerate(data):
        word = word_data["word"]
        start = word_data["start"]
        end = word_data["end"]

        line.append(word_data)
        line_duration += end - start

        temp = " ".join(item["word"] for item in line)


        # Check if adding a new word exceeds the maximum character count or duration
        new_line_chars = len(temp)

        duration_exceeded = line_duration > MaxDuration
        chars_exceeded = new_line_chars > MaxChars
        if idx>0:
          gap = word_data['start'] - data[idx-1]['end']
          # print (word,start,end,gap)
          maxgap_exceeded = gap > MaxGap
        else:
          maxgap_exceeded = False


        if duration_exceeded or chars_exceeded or maxgap_exceeded:
            if line:
                subtitle_line = {
                    "word": " ".join(item["word"] for item in line),
                    "start": line[0]["start"],
                    "end": line[-1]["end"],
                    "textcontents": line
                }
                subtitles.append(subtitle_line)
                line = []
                line_duration = 0
                line_chars = 0


    if line:
        subtitle_line = {
            "word": " ".join(item["word"] for item in line),
            "start": line[0]["start"],
            "end": line[-1]["end"],
            "textcontents": line
        }
        subtitles.append(subtitle_line)

    return subtitles
# Out:
# time: 3.89 ms (started: 2023-10-27 13:23:59 +00:00)

# %%
linelevel_subtitles = split_text_into_lines(wordlevel_info)
print (linelevel_subtitles)
# Out:
# [{'word': " So,  you're", 'start': 7.14, 'end': 12.08, 'textcontents': [{'word': ' So,', 'start': 7.14, 'end': 7.78}, {'word': " you're", 'start': 11.94, 'end': 12.08}]}, {'word': ' running  a  little  late  today.', 'start': 12.08, 'end': 13.5, 'textcontents': [{'word': ' running', 'start': 12.08, 'end': 12.38}, {'word': ' a', 'start': 12.38, 'end': 12.58}, {'word': ' little', 'start': 12.58, 'end': 12.76}, {'word': ' late', 'start': 12.76, 'end': 13.02}, {'word': ' today.', 'start': 13.02, 'end': 13.5}]}, {'word': " And  you  haven't  had  your  fresh", 'start': 13.92, 'end': 15.32, 'textcontents': [{'word': ' And', 'start': 13.92, 'end': 14.24}, {'word': ' you', 'start': 14.24, 'end': 14.38}, {'word': " haven't", 'start': 14.38, 'end': 14.56}, {'word': ' had', 'start': 14.56, 'end': 14.74}, {'word': ' your', 'start': 14.74, 'end': 15.08}, {'word': ' fresh', 'start': 15.08, 'end': 15.32}]}, {'word': ' cup  of  coffee  yet.  No  matter', 'start': 15.32, 'end': 18.18, 'textcontents':
# ...

# %%
for line in linelevel_subtitles:
  json_str = json.dumps(line, indent=4)
  print(json_str)
# Out:
# {
#     "word": " So,  you're",
#     "start": 7.14,
#     "end": 12.08,
#     "textcontents": [
#         {
#             "word": " So,",
#             "start": 7.14,
#             "end": 7.78
#         },
#         {
#             "word": " you're",
#             "start": 11.94,
#             "end": 12.08
#         }
#     ]
# }
# {
#     "word": " running  a  little  late  today.",
#     "start": 12.08,
#     "end": 13.5,
#     "textcontents": [
#         {
#             "word": " running",
#             "start": 12.08,
#             "end": 12.38
#         },
#         {
#             "word": " a",
#             "start": 12.38,
#             "end": 12.58
#         },
#         {
#             "word": " little",
#             "start": 12.58,
#             "end": 12.76
#         },
#         {
#             "word": " late",
#             "start": 12.76,
#             "end": 13.02
#         },
#         {
#             "word": " today.",
#             "start": 13.02,
# ...

# %%
# !pip install -q moviepy==2.0.0.dev2
# !pip install -q imageio==2.25.1
# Out:
# time: 16.4 s (started: 2023-10-27 13:23:59 +00:00)

# %%
# !apt install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# imagemagick is already the newest version (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# time: 1.62 s (started: 2023-10-27 13:24:16 +00:00)

# %%
# !cat /etc/ImageMagick-6/policy.xml | sed 's/none/read,write/g'> /etc/ImageMagick-6/policy.xml
# Out:
# time: 107 ms (started: 2023-10-27 13:24:17 +00:00)

# %%
from moviepy.editor import TextClip, CompositeVideoClip, ColorClip
import numpy as np


def create_caption(textJSON, framesize,font = "Helvetica",color='white', highlight_color='yellow',stroke_color='black',stroke_width=1.5):
    wordcount = len(textJSON['textcontents'])
    full_duration = textJSON['end']-textJSON['start']

    word_clips = []
    xy_textclips_positions =[]

    x_pos = 0
    y_pos = 0
    line_width = 0  # Total width of words in the current line
    frame_width = framesize[0]
    frame_height = framesize[1]

    x_buffer = frame_width*1/10

    max_line_width = frame_width - 2 * (x_buffer)

    fontsize = int(frame_height * 0.075) #7.5 percent of video height

    space_width = ""
    space_height = ""

    for index,wordJSON in enumerate(textJSON['textcontents']):
      duration = wordJSON['end']-wordJSON['start']
      word_clip = TextClip(wordJSON['word'], font = font,fontsize=fontsize, color=color,stroke_color=stroke_color,stroke_width=stroke_width).set_start(textJSON['start']).set_duration(full_duration)
      word_clip_space = TextClip(" ", font = font,fontsize=fontsize, color=color).set_start(textJSON['start']).set_duration(full_duration)
      word_width, word_height = word_clip.size
      space_width,space_height = word_clip_space.size
      if line_width + word_width+ space_width <= max_line_width:
            # Store info of each word_clip created
            xy_textclips_positions.append({
                "x_pos":x_pos,
                "y_pos": y_pos,
                "width" : word_width,
                "height" : word_height,
                "word": wordJSON['word'],
                "start": wordJSON['start'],
                "end": wordJSON['end'],
                "duration": duration
            })

            word_clip = word_clip.set_position((x_pos, y_pos))
            word_clip_space = word_clip_space.set_position((x_pos+ word_width, y_pos))

            x_pos = x_pos + word_width+ space_width
            line_width = line_width+ word_width + space_width
      else:
            # Move to the next line
            x_pos = 0
            y_pos = y_pos+ word_height+10
            line_width = word_width + space_width

            # Store info of each word_clip created
            xy_textclips_positions.append({
                "x_pos":x_pos,
                "y_pos": y_pos,
                "width" : word_width,
                "height" : word_height,
                "word": wordJSON['word'],
                "start": wordJSON['start'],
                "end": wordJSON['end'],
                "duration": duration
            })

            word_clip = word_clip.set_position((x_pos, y_pos))
            word_clip_space = word_clip_space.set_position((x_pos+ word_width , y_pos))
            x_pos = word_width + space_width


      word_clips.append(word_clip)
      word_clips.append(word_clip_space)


    for highlight_word in xy_textclips_positions:

      word_clip_highlight = TextClip(highlight_word['word'], font = font,fontsize=fontsize, color=highlight_color,stroke_color=stroke_color,stroke_width=stroke_width).set_start(highlight_word['start']).set_duration(highlight_word['duration'])
      word_clip_highlight = word_clip_highlight.set_position((highlight_word['x_pos'], highlight_word['y_pos']))
      word_clips.append(word_clip_highlight)

    return word_clips,xy_textclips_positions
# Out:
# time: 8.76 ms (started: 2023-10-27 13:24:17 +00:00)

# %%
from moviepy.editor import TextClip, CompositeVideoClip, concatenate_videoclips,VideoFileClip, ColorClip
input_video = VideoFileClip(videofilename)
frame_size = input_video.size

all_linelevel_splits=[]

for line in linelevel_subtitles:
  out_clips,positions = create_caption(line,frame_size)

  max_width = 0
  max_height = 0

  for position in positions:
    # print (out_clip.pos)
    # break
    x_pos, y_pos = position['x_pos'],position['y_pos']
    width, height = position['width'],position['height']

    max_width = max(max_width, x_pos + width)
    max_height = max(max_height, y_pos + height)

  color_clip = ColorClip(size=(int(max_width*1.1), int(max_height*1.1)),
                       color=(64, 64, 64))
  color_clip = color_clip.set_opacity(.6)
  color_clip = color_clip.set_start(line['start']).set_duration(line['end']-line['start'])

  # centered_clips = [each.set_position('center') for each in out_clips]

  clip_to_overlay = CompositeVideoClip([color_clip]+ out_clips)
  clip_to_overlay = clip_to_overlay.set_position("bottom")


  all_linelevel_splits.append(clip_to_overlay)

input_video_duration = input_video.duration


final_video = CompositeVideoClip([input_video] + all_linelevel_splits)

# Set the audio of the final video to be the same as the input video
final_video = final_video.set_audio(input_video.audio)

# Save the final clip as a video file with the audio included
final_video.write_videofile("output_scrollable.mp4", fps=24, codec="libx264", audio_codec="aac")
# Out:
# Moviepy - Building video output_scrollable.mp4.
# MoviePy - Writing audio in output_scrollableTEMP_MPY_wvf_snd.mp4
# MoviePy - Done.
# Moviepy - Writing video output_scrollable.mp4
# Moviepy - Done !
# Moviepy - video ready output_scrollable.mp4
# time: 55.2 s (started: 2023-10-27 13:24:17 +00:00)

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open("output_scrollable.mp4",'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=600 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=600 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
# time: 53.4 ms (started: 2023-10-27 13:25:13 +00:00)

# %% [markdown]
# ###Generate a SRT File of the Subtitles and then convert the contents of SRT file in regional language

# %%
# !pip install -q pysrt==1.1.2
# Out:
# time: 6.74 s (started: 2023-10-27 13:25:13 +00:00)

# %%
# !apt install imagemagick
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# imagemagick is already the newest version (8:6.9.11.60+dfsg-1.3ubuntu0.22.04.3).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# time: 1.91 s (started: 2023-10-27 13:25:19 +00:00)

# %% [markdown]
# ###Translating the SRT file into Marathi/any other language SRT file

# %%
# !pip install -q googletrans==4.0.0-rc1
# !pip install -q pysrt
# Out:
# time: 11 s (started: 2023-10-27 13:27:07 +00:00)

# %%
import pysrt
from googletrans import Translator

# Load English subtitles
subtitle_path = 'subtitles.srt'
subtitles = pysrt.open(subtitle_path, encoding='utf-8')

# Initialize the translator
translator = Translator()

# Translate each subtitle and create Marathi subtitles
marathi_subtitles = []

for subtitle in subtitles:
    # Translate the subtitle text
    translation = translator.translate(subtitle.text, src='en', dest='mr')
    translated_text = translation.text

    # Retain the original timing
    marathi_subtitle = pysrt.SubRipItem(
        start=subtitle.start,
        end=subtitle.end,
        text=translated_text
    )
    marathi_subtitles.append(marathi_subtitle)

# Save Marathi subtitles to a new file
marathi_subtitle_path = 'marathi_subtitles.srt'
with open(marathi_subtitle_path, 'w', encoding='utf-8') as marathi_file:
    marathi_file.write('\n'.join([str(sub) for sub in marathi_subtitles]))

print('Marathi subtitles saved successfully.')
# Out:
# Marathi subtitles saved successfully.
# time: 5.08 s (started: 2023-10-27 13:27:24 +00:00)

# %%
from googletrans import Translator



translator = Translator()

translated_content = []

for item in wordlevel_info:
    word = item['word']
    translation = translator.translate(word, src='en', dest='mr').text  # Translate from English (en) to Marathi (mr)
    translated_item = {
        'word': translation,
        'start': item['start'],
        'end': item['end']
    }
    translated_content.append(translated_item)

translated_content
# Out:
# [{'word': 'तर,', 'start': 7.14, 'end': 7.78},
#  {'word': 'आपण', 'start': 11.94, 'end': 12.08},
#  {'word': 'धावणे', 'start': 12.08, 'end': 12.38},
#  {'word': 'अ', 'start': 12.38, 'end': 12.58},
#  {'word': 'थोडे', 'start': 12.58, 'end': 12.76},
#  {'word': 'उशीरा', 'start': 12.76, 'end': 13.02},
#  {'word': 'आज.', 'start': 13.02, 'end': 13.5},
#  {'word': 'आणि', 'start': 13.92, 'end': 14.24},
#  {'word': 'आपण', 'start': 14.24, 'end': 14.38},
#  {'word': 'नाही', 'start': 14.38, 'end': 14.56},
#  {'word': 'होते', 'start': 14.56, 'end': 14.74},
#  {'word': 'तुझे', 'start': 14.74, 'end': 15.08},
#  {'word': 'ताजे', 'start': 15.08, 'end': 15.32},
#  {'word': 'कप', 'start': 15.32, 'end': 15.58},
#  {'word': 'च्या', 'start': 15.58, 'end': 15.76},
#  {'word': 'कॉफी', 'start': 15.76, 'end': 16.0},
#  {'word': 'अद्याप.', 'start': 16.0, 'end': 16.38},
#  {'word': 'नाही', 'start': 17.72, 'end': 17.94},
#  {'word': 'बाब', 'start': 17.94, 'end': 18.18},
# ...

# %%
import json
with open('data1.json', 'w') as f:
    json.dump(translated_content, f,indent=4)
# Out:
# time: 1.36 ms (started: 2023-10-27 13:28:18 +00:00)

# %%
import json

for line in linelevel_subtitles:
    text = line['word']  # Assuming 'word' contains the Marathi text
    json_str = json.dumps({'text': text}, indent=4, ensure_ascii=False)
    print(json_str)
# Out:
# {
#     "text": " So,  you're"
# }
# {
#     "text": " running  a  little  late  today."
# }
# {
#     "text": " And  you  haven't  had  your  fresh"
# }
# {
#     "text": " cup  of  coffee  yet.  No  matter"
# }
# {
#     "text": " the  weather  or  traffic,  we"
# }
# {
#     "text": " deliver  fresh  coffee  and  bagels."
# }
# {
#     "text": " The"
# }
# {
#     "text": " Java  Cafe."
# }
# time: 3.28 ms (started: 2023-10-27 13:28:18 +00:00)
